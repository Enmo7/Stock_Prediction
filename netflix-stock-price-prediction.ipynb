# %% [markdown]
# # Libraries

# %%
# Disable all warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np   # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import LSTM
from keras.layers import Dropout

# %% [markdown]
# # Load the Data

# %%
data = pd.read_csv('/kaggle/input/netflix-stock-price-prediction/NFLX.csv')
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1     2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2     2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3     2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4     2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# ...          ...         ...         ...         ...         ...         ...
# 1004  2022-01-31  401.970001  427.700012  398.200012  427.140015  427.140015
# 1005  2022-02-01  432.959991  458.480011  425.540009  457.130005  457.130005
# 1006  2022-02-02  448.250000  451.980011  426.480011  429.480011  429.480011
# 1007  2022-02-03  421.440002  429.260010  404.279999  405.600006  405.600006
# 1008  2022-02-04  407.309998  412.769989  396.640015  410.170013  410.170013
#
#         Volume
# 0     11896100
# 1     12595800
# 2      8981500
# 3      9306700
# 4     16906900
# ...        ...
# 1004  20047500
# 1005  22542300
# 1006  14346000
# 1007   9905200
# 1008   7782400
#
# [1009 rows x 7 columns]

# %%
data.drop('Date', axis = 1, inplace = True)
data
# Out:
#             Open        High         Low       Close   Adj Close    Volume
# 0     262.000000  267.899994  250.029999  254.259995  254.259995  11896100
# 1     247.699997  266.700012  245.000000  265.720001  265.720001  12595800
# 2     266.579987  272.450012  264.329987  264.559998  264.559998   8981500
# 3     267.079987  267.619995  250.000000  250.100006  250.100006   9306700
# 4     253.850006  255.800003  236.110001  249.470001  249.470001  16906900
# ...          ...         ...         ...         ...         ...       ...
# 1004  401.970001  427.700012  398.200012  427.140015  427.140015  20047500
# 1005  432.959991  458.480011  425.540009  457.130005  457.130005  22542300
# 1006  448.250000  451.980011  426.480011  429.480011  429.480011  14346000
# 1007  421.440002  429.260010  404.279999  405.600006  405.600006   9905200
# 1008  407.309998  412.769989  396.640015  410.170013  410.170013   7782400
#
# [1009 rows x 6 columns]

# %% [markdown]
# # Look at The Data

# %%
# Take a look at the form (shape) of the data (Dimensions of Dataset).
data.shape
# Out:
# (1009, 6)

# %%
# Look at the columns names.
data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
# Let's check the data, to see if there is duplicate data or not
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1004    False
# 1005    False
# 1006    False
# 1007    False
# 1008    False
# Length: 1009, dtype: bool

# %%
# We are looking for duplicate rows.
data.duplicated().sum()
# Out:
# 0

# %%
# Checking for missing values
data.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Use the .info() method to find out how many entries there are.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1009 non-null   float64
#  1   High       1009 non-null   float64
#  2   Low        1009 non-null   float64
#  3   Close      1009 non-null   float64
#  4   Adj Close  1009 non-null   float64
#  5   Volume     1009 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 47.4 KB

# %%
# We are looking for types of the columns in the data.
data.dtypes
# Out:
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
# To know and see the number of components or the number of sample of each column in this data.
data.nunique()
# Out:
# Open          976
# High          983
# Low           989
# Close         988
# Adj Close     988
# Volume       1005
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
df = data.copy()
df
# Out:
#             Open        High         Low       Close   Adj Close    Volume
# 0     262.000000  267.899994  250.029999  254.259995  254.259995  11896100
# 1     247.699997  266.700012  245.000000  265.720001  265.720001  12595800
# 2     266.579987  272.450012  264.329987  264.559998  264.559998   8981500
# 3     267.079987  267.619995  250.000000  250.100006  250.100006   9306700
# 4     253.850006  255.800003  236.110001  249.470001  249.470001  16906900
# ...          ...         ...         ...         ...         ...       ...
# 1004  401.970001  427.700012  398.200012  427.140015  427.140015  20047500
# 1005  432.959991  458.480011  425.540009  457.130005  457.130005  22542300
# 1006  448.250000  451.980011  426.480011  429.480011  429.480011  14346000
# 1007  421.440002  429.260010  404.279999  405.600006  405.600006   9905200
# 1008  407.309998  412.769989  396.640015  410.170013  410.170013   7782400
#
# [1009 rows x 6 columns]

# %%
# Matrix form for correlation data
drrr= data.corr()
drrr
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.998605  0.998508  0.996812   0.996812 -0.415838
# High       0.998605  1.000000  0.998203  0.998551   0.998551 -0.400699
# Low        0.998508  0.998203  1.000000  0.998544   0.998544 -0.432116
# Close      0.996812  0.998551  0.998544  1.000000   1.000000 -0.413362
# Adj Close  0.996812  0.998551  0.998544  1.000000   1.000000 -0.413362
# Volume    -0.415838 -0.400699 -0.432116 -0.413362  -0.413362  1.000000

# %%
# We here looking at the data Visualization by heatmap.
plt.figure(figsize=(20,20))
sns.heatmap(drrr)
# Out:
# <Axes: >

# %%
f,ax = plt.subplots(figsize=(20, 20))
sns.heatmap(drrr, annot=True, linewidths=.5, fmt= '.1f',ax=ax)
# Out:
# <Axes: >

# %%
# Original data.
for i in df.loc[:, ~df.columns.isin(["Date", "Volume"])]:
    f = sns.countplot(x=df[i]);
    plt.figure(figsize=(20,20))
    plt.show()

# %%
df.plot(kind='box',subplots=True,layout=(10,10),figsize=(20,20))
plt.show()

# %%
sns.pairplot(df)

# %% [markdown]
# # Splitting

# %%
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# %%
train_data.shape, test_data.shape
# Out:
# ((807, 6), (202, 6))

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Scale

# %%
scaler = MinMaxScaler()

# %%
scalerr = MinMaxScaler()

# %%
train_data_scaled = scaler.fit_transform(train_data)
train_data_scaled
# Out:
# array([[0.17860959, 0.14960206, 0.16969522, 0.17439697, 0.17439697,
#         0.14992077],
#        [0.28898633, 0.26224888, 0.27997145, 0.27364546, 0.27364546,
#         0.10854764],
#        [0.30501932, 0.28738923, 0.30877797, 0.30631203, 0.30631203,
#         0.06049766],
#        ...,
#        [0.67691906, 0.66287127, 0.6698401 , 0.66183209, 0.66183209,
#         0.02491101],
#        [0.09626332, 0.07914141, 0.10282939, 0.10512013, 0.10512013,
#         0.08610638],
#        [0.33054124, 0.33309287, 0.3316983 , 0.35996755, 0.35996755,
#         0.1189803 ]])

# %%
test_data_scaled = scaler.transform(test_data)
test_data_scaled
# Out:
# array([[0.57747095, 0.5857591 , 0.59624089, 0.60416715, 0.60416715,
#         0.07499163],
#        [0.59230423, 0.58091143, 0.56955252, 0.57150058, 0.57150058,
#         0.08023833],
#        [0.5964488 , 0.59491335, 0.59831441, 0.58493084, 0.58493084,
#         0.05016219],
#        ...,
#        [0.11825144, 0.10166625, 0.09696552, 0.09081345, 0.09081345,
#         0.19982609],
#        [0.28200602, 0.27101986, 0.29424097, 0.29827134, 0.29827134,
#         0.04948878],
#        [0.2564841 , 0.23776243, 0.25747474, 0.25381769, 0.25381769,
#         0.14632288]])

# %%
#Creating a data structure with 50 timesteps and 1 output, timestep is our memory size
#In this function we are creating our train data with 50x stock price and next one is 1 scrolled data.
#for example X_tain[0] will be our data's 0 to 49. values
#X_train[1] will be our data's 1 to 50. values
#this 50 is our memory size, it will remember this way what we had before.
X_train=[]
y_train=[]
timesteps=50
for i in range(timesteps,len(train_data_scaled)):
    X_train.append(train_data_scaled[i-timesteps:i,0])
    y_train.append(train_data_scaled[i,0])
X_train,y_train=np.array(X_train),np.array(y_train)

# %%
real_stock_price=test_data.loc[:,["Open"]].values

# %% [markdown]
# # Model

# %% [markdown]
# ## Recurrent Neural Network (RNN)

# %%
regressor=Sequential()
#Adding the first RNN Layer and some Dropout Regularisation
regressor.add(SimpleRNN(units=50,activation="tanh",return_sequences=True,input_shape=(X_train.shape[1],1)))
regressor.add(Dropout(0,2))

#Adding the second RNN Layer and some Dropout Regularisation
regressor.add(SimpleRNN(units=50,activation="tanh",return_sequences=True))
regressor.add(Dropout(0,2))
              
#Adding the third RNN Layer and some Dropout Regularisation              
regressor.add(SimpleRNN(units=50,activation="tanh",return_sequences=True))
regressor.add(Dropout(0,2))

#Adding the third RNN Layer and some Dropout Regularisation              
regressor.add(SimpleRNN(units=50,activation="tanh",return_sequences=True))
regressor.add(Dropout(0,2))

#Adding the fourth RNN Layer and some Dropout Regularisation
regressor.add(SimpleRNN(units=50))
regressor.add(Dropout(0,2))
              
#Adding the output Layer
regressor.add(Dense(units=1))

# %%
regressor.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 50, 50)            2600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  simple_rnn_1 (SimpleRNN)    (None, 50, 50)            5050
#
#  dropout_1 (Dropout)         (None, 50, 50)            0
#
#  simple_rnn_2 (SimpleRNN)    (None, 50, 50)            5050
#
#  dropout_2 (Dropout)         (None, 50, 50)            0
#
#  simple_rnn_3 (SimpleRNN)    (None, 50, 50)            5050
#
#  dropout_3 (Dropout)         (None, 50, 50)            0
#
#  simple_rnn_4 (SimpleRNN)    (None, 50)                5050
#
#  dropout_4 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 22,851
# Trainable params: 22,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compling the RNN
regressor.compile(optimizer="adam",loss="mean_squared_error")

# %%
#Fitting the RNN to the Training set
regressor.fit(X_train,y_train,epochs=50,batch_size=32)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 6s 53ms/step - loss: 0.2054
# Epoch 2/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0619
# Epoch 3/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0570
# Epoch 4/50
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0571
# Epoch 5/50
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0581
# Epoch 6/50
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0570
# Epoch 7/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0563
# Epoch 8/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0578
# Epoch 9/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0624
# Epoch 10/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0576
# Epoch 11/50
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0577
# Epoch 12/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0565
# Epoch 13/50
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0560
# Epoch 14/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0570
# Epoch 15/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0549
# Epoch 16/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0557
# Epoch 17/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0560
# Epoch 18/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0576
# Epoch 19/50
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0546
# Epoch 20/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0544
# Epoch 21/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0531
# Epoch 22/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0529
# Epoch 23/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0521
# Epoch 24/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0515
# Epoch 25/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0510
# Epoch 26/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0480
# Epoch 27/50
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0477
# Epoch 28/50
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0494
# Epoch 29/50
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0435
# Epoch 30/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0437
# Epoch 31/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0423
# Epoch 32/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0409
# Epoch 33/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0407
# Epoch 34/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0396
# Epoch 35/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0351
# Epoch 36/50
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0324
# Epoch 37/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0313
# Epoch 38/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0340
# Epoch 39/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0284
# Epoch 40/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0293
# Epoch 41/50
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0234
# Epoch 42/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0230
# Epoch 43/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0208
# Epoch 44/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0175
# Epoch 45/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0153
# Epoch 46/50
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0154
# Epoch 47/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0140
# Epoch 48/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0118
# Epoch 49/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0123
# Epoch 50/50
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0114

# %%
dataset_total=pd.concat((train_data["Open"],test_data["Open"]), axis=0)
inputs= dataset_total[len(dataset_total)-len(train_data)-timesteps:].values.reshape(-1,1)
inputs=scalerr.fit_transform(inputs)

# %%
#prediction
X_test=[]
for i in range(timesteps,timesteps+len(test_data_scaled)):
    X_test.append(inputs[i-timesteps:i,0])
X_test=np.array(X_test)
X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
predicted_stock_price=regressor.predict(X_test)
predicted_stock_price=scalerr.inverse_transform(predicted_stock_price)#we had scaled between 0-1 data, inversing it
# Out:
# 7/7 [==============================] - 1s 18ms/step

# %%
#visualising
plt.plot(real_stock_price,color="red",label="Real Netflix Stock Price")
plt.plot(predicted_stock_price,color="blue",label="Predicted Netflix Stock Price")
plt.title("Netflix Stock Price Prediction")
plt.xlabel("Time")
plt.ylabel("Stock Price")
plt.legend()
plt.show()

# %% [markdown]
# ## Long Short Term Memory (LSTM)

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units = 1))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10400
#
#  dropout_5 (Dropout)         (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50, 50)            20200
#
#  dropout_6 (Dropout)         (None, 50, 50)            0
#
#  lstm_2 (LSTM)               (None, 50, 50)            20200
#
#  dropout_7 (Dropout)         (None, 50, 50)            0
#
#  lstm_3 (LSTM)               (None, 50, 50)            20200
#
#  dropout_8 (Dropout)         (None, 50, 50)            0
#
#  lstm_4 (LSTM)               (None, 50, 50)            20200
#
#  dropout_9 (Dropout)         (None, 50, 50)            0
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dropout_10 (Dropout)        (None, 50)                0
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 111,451
# Trainable params: 111,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'mean_squared_error', optimizer = 'Adam')

# %%
model.fit(X_train, y_train, epochs = 10, batch_size = 32)
# Out:
# Epoch 1/10
# 24/24 [==============================] - 18s 159ms/step - loss: 0.0803
# Epoch 2/10
# 24/24 [==============================] - 4s 156ms/step - loss: 0.0589
# Epoch 3/10
# 24/24 [==============================] - 4s 152ms/step - loss: 0.0584
# Epoch 4/10
# 24/24 [==============================] - 4s 156ms/step - loss: 0.0613
# Epoch 5/10
# 24/24 [==============================] - 4s 157ms/step - loss: 0.0590
# Epoch 6/10
# 24/24 [==============================] - 4s 157ms/step - loss: 0.0589
# Epoch 7/10
# 24/24 [==============================] - 4s 155ms/step - loss: 0.0595
# Epoch 8/10
# 24/24 [==============================] - 4s 157ms/step - loss: 0.0599
# Epoch 9/10
# 24/24 [==============================] - 4s 162ms/step - loss: 0.0594
# Epoch 10/10
# 24/24 [==============================] - 4s 158ms/step - loss: 0.0589

# %%
dataset_total=pd.concat((train_data["Open"],test_data["Open"]), axis=0)
inputs= dataset_total[len(dataset_total)-len(test_data)-timesteps:].values.reshape(-1,1)
inputs=scalerr.transform(inputs)

# %%
#prediction
X_test=[]
for i in range(timesteps,timesteps+len(test_data)):
    X_test.append(inputs[i-timesteps:i,0])
X_test=np.array(X_test)
X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
predicted_stock_price=model.predict(X_test)
predicted_stock_price=scalerr.inverse_transform(predicted_stock_price)#we had scaled between 0-1 data, inversing it
# Out:
# 7/7 [==============================] - 3s 42ms/step

# %%
#visualising
plt.plot(real_stock_price,color="red",label="Real Netflix Stock Price")
plt.plot(predicted_stock_price,color="blue",label="Predicted Netflix Stock Price")
plt.title("Netflix Stock Price Prediction")
plt.xlabel("Time")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
